# %%
import LanusStats as ls

# %%
transfermarkt = ls.Transfermarkt()

# %%
ls.get_available_pages()
ls.get_available_leagues('Transfermarkt')
# Out:
# ['Primera Division Argentina',
#  'Argentina Copa de la Liga',
#  'Primera Division Chile',
#  'Brasileirao',
#  'LaLiga',
#  'LaLiga 2',
#  'Primera RFEF Grupo 1',
#  'Primera RFEF Grupo 2',
#  'Premier League']

# %%
transfermarkt.get_season_id("2024")
# Out:
# 2023

# %%
transfermarkt.get_league_teams_valuations(league='Premier League', season='2023')
# Out:
#                        Club Squad size Mean age Foreigners Mean market value  \
# 0           Manchester City         34     26.0         21           €33.70m
# 1                Arsenal FC         42     24.0         25           €23.83m
# 2                Chelsea FC         43     25.2         27           €23.14m
# 3         Manchester United         48     25.4         29           €17.66m
# 4              Liverpool FC         39     25.6         24           €20.82m
# 5         Tottenham Hotspur         34     25.9         21           €19.09m
# 6          Newcastle United         38     28.3         22           €14.25m
# 7    Brighton & Hove Albion         42     24.1         28           €12.61m
# 8               Aston Villa         43     25.4         23           €11.85m
# 9   Wolverhampton Wanderers         43     25.8         34           €11.57m
# 10           Leicester City         38     26.4         25           €12.91m
# ...

# %%
transfermarkt.scrape_players_for_teams(team_name='Fc Valencia', team_id='1049', season='2021')
# Out:
# ['#', 'Jugadores', 'F. Nacim./Edad', 'Nac.', 'Club actual', 'Altura', 'Pie', 'Fichado', 'antes', 'Valor de mercado', 'Pais', 'Seg nacionalidad']
#      #           Jugadores              Posicion    Fecha de nac. Altura  \
# 0   13    Jasper Cillessen               Portero  22/04/1989 (32)  1,87m
# 1    1      Jaume Doménech               Portero  05/11/1990 (30)  1,85m
# 2   25     Cristian Rivero               Portero  21/03/1998 (23)  1,88m
# 3   42     Unai Etxebarria               Portero  30/08/1996 (24)  1,88m
# 4    5    Gabriel Paulista       Defensa central  26/11/1990 (30)  1,85m
# 5   12    Mouctar Diakhaby       Defensa central  19/12/1996 (24)  1,92m
# 6    6               Ferro       Defensa central  26/03/1997 (24)  1,91m
# 7    4    Eliaquim Mangala       Defensa central  13/02/1991 (30)  1,87m
# 8   24   Cristiano Piccini       Defensa central  26/09/1992 (28)  1,89m
# 9   31      Guillem Molina       Defensa central  03/05/2000 (21)  1,83m
# ...
